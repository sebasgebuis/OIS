# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv", sep = ',')
data = data.drop("Tijdstempel", axis = 1)

def calc_score(array):
    num1, num2 = array.split('/')
    return round(int(num1) / int(num2) * 100)

data = data.rename({"Wat is uw leeftijd in cijfers?": "leeftijd", 
                    "Wat is uw geslacht?":"geslacht",
                   "Wat is het niveau waaraan u momenteel studeert of heeft gestudeerd, indien u al werkt?": "niveau",
                   "Wat is uw vakgebied of studierichting?": "vakgebied",
                   "Is uw vakgebied of studierichting direct gerelateerd aan technische onderwerpen zoals ICT, kunstmatige intelligentie en AI-generatoren?"
                   : "relatie-vakgebied", "In hoeverre bent u bekend met AI-generatoren?":"bekendheid-AI",
                    'Hoe vaardig acht u uzelf in het begrijpen van de werking van AI-generatoren?': 'vaardigheid-AI',
                   'Hoe regelmatig gebruikt u zelf AI-generatoren in uw studie of werk? (ChatGPT, DALL-E, Bard)':'regelmaat-AI',
                   'Waar heeft u AI-generatoren voorheen voor gebruikt, indien van toepassing?':'gebruik-AI',
                   'Hoeveel vertrouwen heeft u in uw vermogen om onderscheid te maken tussen door AI gegenereerde en authentieke afbeeldingen?'
                   :'vertrouwen-Onderscheid', 'Vul uw starttijd in':'starttijd',
                   'Vul uw eindtijd in:': "eindtijd",
                   'Score': 'score',
                   'Heeft u tijdens de survey nieuwe informatie opgedaan over AI-generatoren die u eerder niet kende?':
                   'nieuwe-kennis',
                   'In hoeverre heeft uw deelname aan deze survey invloed gehad op uw vertrouwen in het onderscheiden van  authentieke en door AI gegenereerde afbeeldingen?':
                   'invloed-survey',
                   'Wat vond u van de moeilijkheidsgraad van de afbeeldingen?': 'moeilijkheid',
                   "Hoeveel foto's denkt u correct te hebben onderscheiden tijdens de survey?": "inschatting"}, axis = 'columns')
data['score'] = data['score'].apply(calc_score)

display(data)
# Out:
#      score leeftijd geslacht                              niveau  \
# 0       57       56    Vrouw                                 HBO
# 1       73       41    Vrouw                                 HBO
# 2       60       36    Vrouw                                 HBO
# 3       60       57    Vrouw                                 MBO
# 4       60       55    Vrouw                                 HBO
# ..     ...      ...      ...                                 ...
# 215     67       36    Vrouw                   Middelbare school
# 216     80       20      Man  Universitair (Bachelor/Master/PhD)
# 217     73       30    Vrouw                                 HBO
# 218    100       32      Man                                 HBO
# 219     70       64    Vrouw  Universitair (Bachelor/Master/PhD)
#
#                   vakgebied relatie-vakgebied  bekendheid-AI  vaardigheid-AI  \
# 0                  Toerisme               Nee              3               3
# 1                 Onderwijs               Nee              3               3
# 2     Reclame communicatie                Nee              1               1
# 3                         .               Nee              1               1
# 4    Schoonheidsspecialiste               Nee              4               1
# ..                      ...               ...            ...             ...
# 215             E-commerce                Nee              3               2
# 216         Informatiekunde                Ja              4               4
# 217  marketing/communicatie        een beetje              2               3
# 218                Techniek               Nee              4               3
# 219                    Film               Nee              1               1
#
#      regelmaat-AI                                         gebruik-AI  ...  \
# 0               3                        Teksten genereren (ChatGPT)  ...
# 1               3                        Teksten genereren (ChatGPT)  ...
# 2               1                                Niet van toepassing  ...
# 3               1                                Niet van toepassing  ...
# 4               1                                Niet van toepassing  ...
# ..            ...                                                ...  ...
# 215             3                        Teksten genereren (ChatGPT)  ...
# 216             3                        Teksten genereren (ChatGPT)  ...
# 217             4  Teksten genereren (ChatGPT), Afbeeldingen gene...  ...
# 218             2        Afbeeldingen genereren (DALL-E, Midjourney)  ...
# 219             1                                Niet van toepassing  ...
#
#      Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. .27  \
# 0                                    Getekende beelden
# 1                                         Zelfde hoofd
# 2                                                  NaN
# 3                                    Spreekt voor zich
# 4                                                  NaN
# ..                                                 ...
# 215                                          Scenario
# 216                       beetje veel vladimir poetins
# 217                                    zelfde personen
# 218                    Meerdere poetins en rare handen
# 219                                   Vreemde hoofden
#
#     29: Is deze foto echt of nep?  \
# 0                            Echt
# 1                            Echt
# 2                            Echt
# 3                            Echt
# 4                            Echt
# ..                            ...
# 215                          Echt
# 216                          Echt
# 217                          Echt
# 218                          Echt
# 219                          Echt
#
#     Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. .28  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
#
#     30: Is deze foto echt of nep?  \
# 0                             Nep
# 1                            Echt
# 2                             Nep
# 3                             Nep
# 4                             Nep
# ..                            ...
# 215                           Nep
# 216                           Nep
# 217                           Nep
# 218                           Nep
# 219                           Nep
#
#     Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. .29  \
# 0                                          Gefotoshopt
# 1                                                  NaN
# 2                                                  NaN
# 3                                    Persoon te onecht
# 4                                                  NaN
# ..                                                 ...
# 215                               Scenario en kleuren
# 216                                     onreallistisch
# 217                                             vormen
# 218  Raar hoofd, vreemde belichting, sterk perspectief
# 219                                      Vreemd hoofd
#
#      eindtijd nieuwe-kennis invloed-survey moeilijkheid inschatting
# 0    21:20:00            Ja              2            4           2
# 1    21:22:00           Nee              3            5           5
# 2    21:23:00           Nee              3            3           4
# 3    21:24:00           Nee              3            3           6
# 4    21:26:00           Nee              2            4           6
# ..        ...           ...            ...          ...         ...
# 215  10:24:00           Nee              1            5           4
# 216  13:54:00           Nee              5            2           8
# 217  15:26:00           Nee              1            4           5
# 218  19:53:00           Nee              3            3           9
# 219  20:08:00            Ja              4            3           8
#
# [220 rows x 77 columns]

# %%
def niveau_clean(cel):
    if cel == "Universitair (Bachelor/Master/PhD)":
        return "Universitair"
    else:
        return cel
    
data['niveau'] = data['niveau'].apply(niveau_clean)
display(data)
# Out:
#      score leeftijd geslacht             niveau               vakgebied  \
# 0       57       56    Vrouw                HBO                Toerisme
# 1       73       41    Vrouw                HBO               Onderwijs
# 2       60       36    Vrouw                HBO   Reclame communicatie
# 3       60       57    Vrouw                MBO                       .
# 4       60       55    Vrouw                HBO  Schoonheidsspecialiste
# ..     ...      ...      ...                ...                     ...
# 215     67       36    Vrouw  Middelbare school             E-commerce
# 216     80       20      Man       Universitair         Informatiekunde
# 217     73       30    Vrouw                HBO  marketing/communicatie
# 218    100       32      Man                HBO                Techniek
# 219     70       64    Vrouw       Universitair                    Film
#
#     relatie-vakgebied  bekendheid-AI  vaardigheid-AI  regelmaat-AI  \
# 0                 Nee              3               3             3
# 1                 Nee              3               3             3
# 2                 Nee              1               1             1
# 3                 Nee              1               1             1
# 4                 Nee              4               1             1
# ..                ...            ...             ...           ...
# 215               Nee              3               2             3
# 216                Ja              4               4             3
# 217        een beetje              2               3             4
# 218               Nee              4               3             2
# 219               Nee              1               1             1
#
#                                             gebruik-AI  ...  \
# 0                          Teksten genereren (ChatGPT)  ...
# 1                          Teksten genereren (ChatGPT)  ...
# 2                                  Niet van toepassing  ...
# 3                                  Niet van toepassing  ...
# 4                                  Niet van toepassing  ...
# ..                                                 ...  ...
# 215                        Teksten genereren (ChatGPT)  ...
# 216                        Teksten genereren (ChatGPT)  ...
# 217  Teksten genereren (ChatGPT), Afbeeldingen gene...  ...
# 218        Afbeeldingen genereren (DALL-E, Midjourney)  ...
# 219                                Niet van toepassing  ...
#
#      Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. .27  \
# 0                                    Getekende beelden
# 1                                         Zelfde hoofd
# 2                                                  NaN
# 3                                    Spreekt voor zich
# 4                                                  NaN
# ..                                                 ...
# 215                                          Scenario
# 216                       beetje veel vladimir poetins
# 217                                    zelfde personen
# 218                    Meerdere poetins en rare handen
# 219                                   Vreemde hoofden
#
#     29: Is deze foto echt of nep?  \
# 0                            Echt
# 1                            Echt
# 2                            Echt
# 3                            Echt
# 4                            Echt
# ..                            ...
# 215                          Echt
# 216                          Echt
# 217                          Echt
# 218                          Echt
# 219                          Echt
#
#     Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. .28  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
#
#     30: Is deze foto echt of nep?  \
# 0                             Nep
# 1                            Echt
# 2                             Nep
# 3                             Nep
# 4                             Nep
# ..                            ...
# 215                           Nep
# 216                           Nep
# 217                           Nep
# 218                           Nep
# 219                           Nep
#
#     Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. .29  \
# 0                                          Gefotoshopt
# 1                                                  NaN
# 2                                                  NaN
# 3                                    Persoon te onecht
# 4                                                  NaN
# ..                                                 ...
# 215                               Scenario en kleuren
# 216                                     onreallistisch
# 217                                             vormen
# 218  Raar hoofd, vreemde belichting, sterk perspectief
# 219                                      Vreemd hoofd
#
#      eindtijd nieuwe-kennis invloed-survey moeilijkheid inschatting
# 0    21:20:00            Ja              2            4           2
# 1    21:22:00           Nee              3            5           5
# 2    21:23:00           Nee              3            3           4
# 3    21:24:00           Nee              3            3           6
# 4    21:26:00           Nee              2            4           6
# ..        ...           ...            ...          ...         ...
# 215  10:24:00           Nee              1            5           4
# 216  13:54:00           Nee              5            2           8
# 217  15:26:00           Nee              1            4           5
# 218  19:53:00           Nee              3            3           9
# 219  20:08:00            Ja              4            3           8
#
# [220 rows x 77 columns]

# %%
def bekendheid(cel):
    if cel != "Nee":
        return "Ja"
    else:
        return "Nee"

data['relatie-vakgebied'] = data['relatie-vakgebied'].apply(bekendheid)

# %%
fotodic = {str(i)+": Is deze foto echt of nep?": "foto-"+str(i) for i in range(1,31)}
fotodescr = {"Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. ." + str(i): "toelichting-"+str(i+1) for i in range(1,31)}
enekkrkolomxdd = {"Indien u nep heeft geselecteerd, licht toe welke aspecten van de afbeelding onnatuurlijk zijn voor u. ":"toelichting-1"}
dic = fotodic | fotodescr | enekkrkolomxdd
data = data.rename(dic, axis = 'columns')

# %%
def omzet_tijd(tijd):
    minuten = 0
    minuten += int(tijd.split(":")[0]) * 60
    minuten += int(tijd.split(":")[1])
    return minuten

data['starttijd'] = data['starttijd'].apply(omzet_tijd) 
data['eindtijd'] = data['eindtijd'].apply(omzet_tijd) 
data['tijd'] = data['eindtijd'] - data['starttijd']

# %%
display(data)
# Out:
#      score leeftijd geslacht             niveau               vakgebied  \
# 0       57       56    Vrouw                HBO                Toerisme
# 1       73       41    Vrouw                HBO               Onderwijs
# 2       60       36    Vrouw                HBO   Reclame communicatie
# 3       60       57    Vrouw                MBO                       .
# 4       60       55    Vrouw                HBO  Schoonheidsspecialiste
# ..     ...      ...      ...                ...                     ...
# 215     67       36    Vrouw  Middelbare school             E-commerce
# 216     80       20      Man       Universitair         Informatiekunde
# 217     73       30    Vrouw                HBO  marketing/communicatie
# 218    100       32      Man                HBO                Techniek
# 219     70       64    Vrouw       Universitair                    Film
#
#     relatie-vakgebied  bekendheid-AI  vaardigheid-AI  regelmaat-AI  \
# 0                 Nee              3               3             3
# 1                 Nee              3               3             3
# 2                 Nee              1               1             1
# 3                 Nee              1               1             1
# 4                 Nee              4               1             1
# ..                ...            ...             ...           ...
# 215               Nee              3               2             3
# 216                Ja              4               4             3
# 217                Ja              2               3             4
# 218               Nee              4               3             2
# 219               Nee              1               1             1
#
#                                             gebruik-AI  ...  foto-29  \
# 0                          Teksten genereren (ChatGPT)  ...     Echt
# 1                          Teksten genereren (ChatGPT)  ...     Echt
# 2                                  Niet van toepassing  ...     Echt
# 3                                  Niet van toepassing  ...     Echt
# 4                                  Niet van toepassing  ...     Echt
# ..                                                 ...  ...      ...
# 215                        Teksten genereren (ChatGPT)  ...     Echt
# 216                        Teksten genereren (ChatGPT)  ...     Echt
# 217  Teksten genereren (ChatGPT), Afbeeldingen gene...  ...     Echt
# 218        Afbeeldingen genereren (DALL-E, Midjourney)  ...     Echt
# 219                                Niet van toepassing  ...     Echt
#
#      toelichting-29 foto-30  \
# 0               NaN     Nep
# 1               NaN    Echt
# 2               NaN     Nep
# 3               NaN     Nep
# 4               NaN     Nep
# ..              ...     ...
# 215             NaN     Nep
# 216             NaN     Nep
# 217             NaN     Nep
# 218             NaN     Nep
# 219             NaN     Nep
#
#                                         toelichting-30 eindtijd nieuwe-kennis  \
# 0                                          Gefotoshopt     1280            Ja
# 1                                                  NaN     1282           Nee
# 2                                                  NaN     1283           Nee
# 3                                    Persoon te onecht     1284           Nee
# 4                                                  NaN     1286           Nee
# ..                                                 ...      ...           ...
# 215                               Scenario en kleuren       624           Nee
# 216                                     onreallistisch      834           Nee
# 217                                             vormen      926           Nee
# 218  Raar hoofd, vreemde belichting, sterk perspectief     1193           Nee
# 219                                      Vreemd hoofd      1208            Ja
#
#     invloed-survey moeilijkheid inschatting tijd
# 0                2            4           2    8
# 1                3            5           5    9
# 2                3            3           4    3
# 3                3            3           6    7
# 4                2            4           6    3
# ..             ...          ...         ...  ...
# 215              1            5           4   23
# 216              5            2           8   10
# 217              1            4           5   11
# 218              3            3           9   23
# 219              4            3           8    8
#
# [220 rows x 78 columns]

# %%
data.to_csv("data_clean.csv")
